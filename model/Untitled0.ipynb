# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.2

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("Grass",limit=30,output_dir = 'images')
# Out:
# [%] Downloading Images to /content/images/Grass
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/1/13/Green_Grass.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/d/da/Grass_closeup.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://eskipaper.com/images/grass-backgrounds-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://theseamanmom.com/wp-content/uploads/2016/07/IMG_7686.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://thecreativeflux.files.wordpress.com/2013/04/img_4168.jpg
# [Error]Invalid image, not saving http://thecreativeflux.files.wordpress.com/2013/04/img_4168.jpg
#
# [!] Issue getting: http://thecreativeflux.files.wordpress.com/2013/04/img_4168.jpg
# [!] Error:: Invalid image, not saving http://thecreativeflux.files.wordpress.com/2013/04/img_4168.jpg
#
# [%] Downloading Image #5 from http://upload.wikimedia.org/wikipedia/commons/9/96/Grass-JW.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://upload.wikimedia.org/wikipedia/commons/6/68/Grass_dsc08672-nevit.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://3.bp.blogspot.com/-iioNUcismpA/TfPgo4TZPtI/AAAAAAAAAP0/czLib5LRDTM/s1600/grass_TF1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://www.changecompanies.net/blog/leadingwithheart/wp-content/uploads/sites/2/2022/07/grass.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://anokatony.files.wordpress.com/2010/04/grass.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://upload.wikimedia.org/wikipedia/commons/a/a6/Grass_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://bgfons.com/upload/grass_texture218.jpg
# [Error]Invalid image, not saving http://bgfons.com/upload/grass_texture218.jpg
#
# [!] Issue getting: http://bgfons.com/upload/grass_texture218.jpg
# [!] Error:: Invalid image, not saving http://bgfons.com/upload/grass_texture218.jpg
#
# [%] Downloading Image #11 from https://www.lawnstarter.com/blog/wp-content/uploads/2017/12/Raleigh-St-Augustine.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://www.myfreetextures.com/wp-content/uploads/2015/01/deep-green-grass-texture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://vignette.wikia.nocookie.net/gemipedia/images/f/f8/Grass.jpg/revision/latest?cb=20150109003215
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://wtop.com/wp-content/uploads/2016/05/grass_ts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://c1.staticflickr.com/3/2115/2420997341_756066f954_z.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://b.rgbimg.com/cache1nGANW/users/b/br/branox/600/mi2ZCSq.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://mameara.com/wp-content/uploads/2010/09/Grass_img.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://sustainablelivestocknutrition.com/wp-content/uploads/2014/03/grass_grasses_green_274133_h.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://www.familyhandyman.com/wp-content/uploads/2020/07/lumpy-lawn-GettyImages-180809519.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://c.pxhere.com/photos/0f/68/grass_blades_of_grass_nature_meadow_close_green-931358.jpg!d
# [%] File Downloaded !
#
# [%] Downloading Image #21 from http://www.dodgerthoughts.com/wp-content/uploads/2012/04/grass11.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from http://s8.picofile.com/file/8364312876/grass_02.jpg
# [!] Issue getting: http://s8.picofile.com/file/8364312876/grass_02.jpg
# [!] Error:: <urlopen error timed out>
# [%] Downloading Image #22 from https://external-preview.redd.it/V9nyr9kQ3LzhHiFQDw806L-mKXME9P9y4baWI-Oq2XE.jpg?auto=webp&amp;s=080b82dbe60d89dc52833784c9dbe41bfb780040
# [Error]Invalid image, not saving https://external-preview.redd.it/V9nyr9kQ3LzhHiFQDw806L-mKXME9P9y4baWI-Oq2XE.jpg?auto=webp&amp;s=080b82dbe60d89dc52833784c9dbe41bfb780040
#
# [!] Issue getting: https://external-preview.redd.it/V9nyr9kQ3LzhHiFQDw806L-mKXME9P9y4baWI-Oq2XE.jpg?auto=webp&amp;s=080b82dbe60d89dc52833784c9dbe41bfb780040
# [!] Error:: Invalid image, not saving https://external-preview.redd.it/V9nyr9kQ3LzhHiFQDw806L-mKXME9P9y4baWI-Oq2XE.jpg?auto=webp&amp;s=080b82dbe60d89dc52833784c9dbe41bfb780040
#
# [%] Downloading Image #22 from https://i1.wp.com/www.gardeningknowhow.com/wp-content/uploads/2019/08/low-growing-grass.jpg?fit=1600%2C1064&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://1.bp.blogspot.com/-t_cFATuwJuo/TWJRV-R6iwI/AAAAAAAAAHI/IHkDcqtcOo4/s320/grass.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://b.rgbimg.com/cache1ntK1z/users/r/ro/robby_m/600/dMNqfd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://www.writinglisa.com/wp-content/uploads/green-grass1.jpg
# [!] Issue getting: http://www.writinglisa.com/wp-content/uploads/green-grass1.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #25 from https://www.americanflagshiponline.com/wp-content/gallery/American Flagship Gallery/greengrass.jpg
# [!] Issue getting: https://www.americanflagshiponline.com/wp-content/gallery/American Flagship Gallery/greengrass.jpg
# [!] Error:: URL can't contain control characters. '/wp-content/gallery/American Flagship Gallery/greengrass.jpg' (found at least ' ')
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #25 from http://s3.amazonaws.com/mtssdhosting/wavgroup.com/wp-content/uploads/2015/07/15084431/Grass.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://lawnstarter.com/blog/wp-content/uploads/2015/01/Yellow-st-augustine-lawn-1024x768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://acrosstheboreddotcom.files.wordpress.com/2012/11/grass.png
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://lawnstarter.com/blog/wp-content/uploads/2015/03/floratam1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://images.pexels.com/photos/72296/pexels-photo-72296.jpeg?cs=srgb&amp;dl=field-grass-lawn-72296.jpg&amp;fm=jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://farm3.staticflickr.com/2115/2420997341_756066f954_z.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.

# %%
downloader.download("Stone",limit=30,output_dir = 'images')
# Out:
# [%] Downloading Images to /content/images/Stone
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.texturex.com/wp-content/uploads/2018/03/Stone-Texture-wall-large-rock-grey-image.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 
jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://jooinn.com/images/stone-floor-5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://i0.wp.com/aussietecture.com.au/wp-content/uploads/2020/01/eyre.jpg?ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://refpenny.files.wordpress.com/2009/05/stone.jpg
# [Error]Invalid image, not saving http://refpenny.files.wordpress.com/2009/05/stone.jpg
#
# [!] Issue getting: http://refpenny.files.wordpress.com/2009/05/stone.jpg
# [!] Error:: Invalid image, not saving http://refpenny.files.wordpress.com/2009/05/stone.jpg
#
# [%] Downloading Image #24 from http://1.bp.blogspot.com/_2kDJZYhqJ9I/TTh3mVmaj3I/AAAAAAAAAXM/XSoboQYxLh8/s1600/texturestone3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://usenaturalstone.org/wp-content/uploads/2016/08/Thin-Veneer-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://cdn.pixabay.com/photo/2014/05/14/13/36/stones-344095_1280.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #27 from https://1.bp.blogspot.com/-uCxHBaR4XMg/UCuJrvQNfsI/AAAAAAAAFPY/i8SV_apQFn4/s1600/Stone_Wallpaper_6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://www.myfreetextures.com/wp-content/uploads/2011/06/2008-07-16_IMGP7587.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://i.pinimg.com/originals/dd/da/df/dddadf06a3c68e28561bf6552335f516.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Moelen.jpg/220px-Moelen.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.

# %%
downloader.download("road",limit=30,output_dir = 'images')
# Out:
# [%] Downloading Images to /content/images/road
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://rvthing.files.wordpress.com/2010/10/road.jpg
# [Error]Invalid image, not saving http://rvthing.files.wordpress.com/2010/10/road.jpg
#
# [!] Issue getting: http://rvthing.files.wordpress.com/2010/10/road.jpg
# [!] Error:: Invalid image, not saving http://rvthing.files.wordpress.com/2010/10/road.jpg
#
# [%] Downloading Image #1 from https://weknowyourdreams.com/images/road/road-14.jpg
# [!] Issue getting: https://weknowyourdreams.com/images/road/road-14.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)>
# [%] Downloading Image #1 from http://fullhdpictures.com/wp-content/uploads/2015/04/Awesome-Road-Wallpapers.jpg
# [!] Issue getting: http://fullhdpictures.com/wp-content/uploads/2015/04/Awesome-Road-Wallpapers.jpg
# [!] Error:: <urlopen error [Errno -3] Temporary failure in name resolution>
# [%] Downloading Image #1 from https://www.sabre-roads.org.uk/wiki/images/d/d2/Mount_Road.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://2.bp.blogspot.com/-3KCxAq0vQOo/Tt6eqkhQMXI/AAAAAAAABVU/V3qP6vi0His/s1600/2011_road_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i0.wp.com/www.publicdomainpictures.net/pictures/110000/velka/empty-road-in-american-west.jpg?ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://images4.alphacoders.com/296/296506.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://cdn.wallpapersafari.com/45/91/WTF0EG.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.chill.ie/images/road-empty.jpg
# [%] File Downloaded !
#
# [%] Downloading Image
jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 30 Images on Page 3.
#
# ===============================================
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 30 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #28 from https://eskipaper.com/images/road-wallpaper-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://www.baylorbarbee.com/wp-content/uploads/2016/09/bg_road2.jpg
# [!] Issue getting: https://www.baylorbarbee.com/wp-content/uploads/2016/09/bg_road2.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #29 from https://images3.alphacoders.com/228/22857.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://ww1.prweb.com/prfiles/2013/04/22/10660607/road.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.

# %%
# Preprocessing part
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

# %%
target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['Grass','Stone','road']

for category in CATEGORIES:
  class_num = CATEGORIES.index(category)
  path = os.path.join(DATADIR,category)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))
    #plt.imshow(img_array)
    img_resized = resize(img_array,(150,150,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
    target.append(class_num)
flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

# %%
#split data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(flat_data,target,test_size = 0.3, random_state = 42)

# %%
#Classification algorithm
#We will be using SVM supervised learning algorithm
from sklearn.model_selection import GridSearchCV
from sklearn import svm
param_grid = [
              {'C':[1,10,100,1000],'kernel':['linear']},
              {'C':[1,10,100,1000],'gamma':[0.001,0.0001] ,'kernel':['rbf']}
]

svc = svm.SVC( probability = True )
clf = GridSearchCV(svc,param_grid)
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']}])

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8888888888888888

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[8, 0, 1],
#        [0, 8, 0],
#        [1, 1, 8]])

# %%
import pickle
pickle.dump(clf,open('img_model.p','wb'))

# %%
model = pickle.load(open('img_model.p','rb'))

# %%
#Testing a brand new image
flat_data = []
url = input('Enter your URL')
img = imread(url)
img_resized = resize(img,(150,150,3))
flat_data.append(img_resized.flatten())
flat_data = np.array(flat_data)
print(img.shape)
plt.imshow(img_resized)
y_out = model.predict(flat_data)
y_out = CATEGORIES[y_out[0]]
if(y_out != "road"):
  print(f'PREDICTED OUTPUT: {y_out} Mountain')
else:
  print(f'PREDICTED OUTPUT: {y_out}')
# Out:
# Enter your URLhttps://images.unsplash.com/photo-1501854140801-50d01698950b?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&auto=format&fit=crop&w=2600&q=80
# (1548, 2600, 3)
# PREDICTED OUTPUT: Grass Mountain
